# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Bar plot of every 

names = ['beer', 'wine', 'spirit']
i = 0
for name in names:
    df = pd.read_csv("../AnalysisData/{}_top_10".format(name))
    fig = df.plot(x='country', y='{}_servings'.format(name), rot=1, kind='barh', figsize=[5,5], title="Top 10 contries in drinking {}".format(name)).get_figure()
    fig.savefig('../Documents/images/{}_top_10.png'.format(name), dpi=300)
    i += 1
